# %% [markdown]
# # Notebook 4: Images in Topic Search (Placeholder)
#
# This placeholder notebook was added to align with the workshop agenda.
# Add image-captioning and image-aware retrieval content here.

# %%
# TODO: add bonus image retrieval exercise code
